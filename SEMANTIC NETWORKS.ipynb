# %% [markdown]
# # SEMANTIC NETWORKS

# %% [markdown]
# # Our dear friend Mark who lives in California plays soccer in a club named spinoff.Since he is new to California and he loves pets,he bought a cat mark is a student who studies in a California State University

# %% [markdown]
# # Statements

# %%
#Mark is a student in California State University(CSU)
#Mark has a Cat
#Mark lives in California 
#Mark plays Soccer
#Mark is a part of Spin off
#Cat is an animal
#Mark loves Animal

# %% [markdown]
# # 1. Importing library

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\sn56.cse2-25\anaconda3\.1\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sn56.cse2-25\anaconda3\.1\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\sn56.cse2-25\anaconda3\.1\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sn56.cse2-25\anaconda3\.1\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sn56.cse2-25\anaconda3\.1\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\sn56.cse2-25\anaconda3\.1\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\sn56.cse2-25\anaconda3\.1\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sn56.cse2-25\anaconda3\.1\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sn56.cse2-25\anaconda3\.1\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sn56.cse2-25\anaconda3\.1\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sn56.cse2-25\anaconda3\.1\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# # 2.Create a Directed Graph

# %%
graph_Mark=nx.DiGraph(Info="Mark's Details")

# %% [markdown]
# # 3.Create Nodes along with Positions

# %%
graph_Mark.add_node("Mark",pos=(0,0))
graph_Mark.add_node("Cat",pos=(-2,6))
graph_Mark.add_node("Student",pos=(-2,-5))
graph_Mark.add_node("animal",pos=(1,6))
graph_Mark.add_node("California",pos=(4,6))
graph_Mark.add_node("Spinoff",pos=(-5,-5))
graph_Mark.add_node("Soccer",pos=(-5,2))
graph_Mark.add_node("SportsClub",pos=(0,-8))
graph_Mark.add_node("CSU",pos=(5,-1))
pos=nx.get_node_attributes(graph_Mark,"pos")

# %% [markdown]
# # 4.Creat edges with weight(Relationship)

# %%
graph_Mark.add_edge("Mark","Cat",weight="has a")
graph_Mark.add_edge("Mark","Student",weight="is a")
graph_Mark.add_edge("Cat","animal",weight="is a")
graph_Mark.add_edge("Mark","Soccer",weight="plays")
graph_Mark.add_edge("Mark","Spinoff",weight="is a part of")
graph_Mark.add_edge("Mark","California",weight="lives in")
graph_Mark.add_edge("Mark","animal",weight="loves")
graph_Mark.add_edge("Student","CSU",weight="in")
graph_Mark.add_edge("Spinoff","SportsClub",weight="is in")
graph_Mark.add_edge("CSU","California",weight="is in")
weight=nx.get_edge_attributes(graph_Mark,"weight")

# %% [markdown]
# # 5.Plot the Graph

# %%
plt.figure()
nx.draw_networkx(graph_Mark,pos,font_weight='bold',node_size=2000,font_size=7)
nx.draw_networkx_edge_labels(graph_Mark,pos,edge_labels=weight)
# Out:
# <img src="data:image/png;base64,..." width="640">
# {('Mark', 'Cat'): Text(-1.0, 3.0, 'has a'),
#  ('Mark', 'Student'): Text(-1.0, -2.5, 'is a'),
#  ('Mark', 'Soccer'): Text(-2.5, 1.0, 'plays'),
#  ('Mark', 'Spinoff'): Text(-2.5, -2.5, 'is a part of'),
#  ('Mark', 'California'): Text(2.0, 3.0, 'lives in'),
#  ('Mark', 'animal'): Text(0.5, 3.0, 'loves'),
#  ('Cat', 'animal'): Text(-0.5, 6.0, 'is a'),
#  ('Student', 'CSU'): Text(1.5, -3.0, 'in'),
#  ('Spinoff', 'SportsClub'): Text(-2.5, -6.5, 'is in'),
#  ('CSU', 'California'): Text(4.5, 2.5, 'is in')}
